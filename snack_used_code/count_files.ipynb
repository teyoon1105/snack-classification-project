# %%
import os

# 최상위 디렉토리 경로
train_path = "D:/classification_data_resize/train/Quant_train_images"

# 클래스 폴더 목록 가져오기
class_list = os.listdir(train_path)

# 결과를 저장할 딕셔너리
result = {}

# 각 클래스 폴더에 대해 Q1~Q5 폴더 순회
for class_name in class_list:
    class_path = os.path.join(train_path, class_name)
    q_count = {}
    
    # Q1 ~ Q5 폴더에 대해 파일 개수 세기
    for q in range(1, 6):
        q_folder_name = f"Q{q}"
        q_folder_path = os.path.join(class_path, q_folder_name)
        
        if os.path.isdir(q_folder_path):
            # Q 폴더에 있는 파일 개수 세기
            file_count = len([f for f in os.listdir(q_folder_path) if os.path.isfile(os.path.join(q_folder_path, f))])
            q_count[q_folder_name] = file_count
        else:
            # Q 폴더가 없는 경우 0으로 설정
            q_count[q_folder_name] = 0
    
    # 결과 저장
    result[class_name] = q_count

# 결과 출력
for class_name, counts in result.items():
    print(f"{class_name}:")
    for q_folder, count in counts.items():
        print(f"  {q_folder}: {count}장")
# Out:
# Albap:
#   Q1: 92장
#   Q2: 85장
#   Q3: 87장
#   Q4: 87장
#   Q5: 92장
# Altang:
#   Q1: 86장
#   Q2: 88장
#   Q3: 88장
#   Q4: 88장
#   Q5: 88장
# Budaejjigae:
#   Q1: 84장
#   Q2: 88장
#   Q3: 91장
#   Q4: 90장
#   Q5: 92장
# Byeongeojjim:
#   Q1: 88장
#   Q2: 86장
#   Q3: 86장
#   Q4: 79장
#   Q5: 85장
# ChaesoTwigim:
#   Q1: 88장
#   Q2: 88장
#   Q3: 88장
#   Q4: 89장
#   Q5: 88장
# ChamchiMayoSamgakKimbap:
#   Q1: 86장
#   Q2: 87장
#   Q3: 88장
#   Q4: 88장
#   Q5: 89장
# ChickenWing:
#   Q1: 88장
#   Q2: 88장
#   Q3: 88장
#   Q4: 88장
#   Q5: 88장
# ChonggakKimchi:
#   Q1: 88장
#   Q2: 88장
#   Q3: 88장
#   Q4: 88장
#   Q5: 87장
# CornSoup:
#   Q1: 86장
#   Q2: 95장
#   Q3: 87장
#   Q4: 84장
#   Q5: 88장
# CreamSauceSpaghetti:
#   Q1: 88장
#   Q2: 91장
#   Q3: 88장
#   Q4: 89장
#   Q5: 92장
# CurryRice:
#   Q1: 88장
#   Q2: 87장
#   Q3: 87장
#   Q4: 87장
#   Q5: 85장
# Dakbokkeumtang:
#   Q1: 83장
#   Q2: 88장
#   Q3: 88장
#   Q4: 87장
#   Q5: 88장
# Dakgalbi:
#   Q1: 96장
#   Q2: 91장
#   Q3: 88장
#   Q4: 88장
#   Q5: 88장
# Dakjuk:
# ...

# %%
import os

# 최상위 디렉토리 경로
train_path = "D:/classification_data_resize/train/Quant_train_images"

# 클래스 폴더 목록 가져오기
class_list = os.listdir(train_path)

# 결과를 저장할 딕셔너리
result = {}
all_counts = []  # 모든 파일 개수를 저장할 리스트

# 각 클래스 폴더에 대해 Q1~Q5 폴더 순회
for class_name in class_list:
    class_path = os.path.join(train_path, class_name)
    q_count = {}
    
    # Q1 ~ Q5 폴더에 대해 파일 개수 세기
    for q in range(1, 6):
        q_folder_name = f"Q{q}"
        q_folder_path = os.path.join(class_path, q_folder_name)
        
        if os.path.isdir(q_folder_path):
            # Q 폴더에 있는 파일 개수 세기
            file_count = len([f for f in os.listdir(q_folder_path) if os.path.isfile(os.path.join(q_folder_path, f))])
            q_count[q_folder_name] = file_count
            all_counts.append(file_count)  # 파일 개수를 리스트에 추가
        else:
            # Q 폴더가 없는 경우 0으로 설정
            q_count[q_folder_name] = 0
            all_counts.append(0)  # 0을 리스트에 추가
    
    # 결과 저장
    result[class_name] = q_count

# 결과 출력
for class_name, counts in result.items():
    print(f"{class_name}:")
    for q_folder, count in counts.items():
        print(f"  {q_folder}: {count}장")

# 전체 파일 개수의 최소값과 최대값 계산
min_count = min(all_counts)
max_count = max(all_counts)

# 최소값과 최대값 출력
print("\n전체 Q 폴더의 파일 개수")
print(f"최소 파일 개수: {min_count}장")
print(f"최대 파일 개수: {max_count}장")
# Out:
# Albap:
#   Q1: 92장
#   Q2: 85장
#   Q3: 87장
#   Q4: 87장
#   Q5: 92장
# Altang:
#   Q1: 86장
#   Q2: 88장
#   Q3: 88장
#   Q4: 88장
#   Q5: 88장
# Budaejjigae:
#   Q1: 84장
#   Q2: 88장
#   Q3: 91장
#   Q4: 90장
#   Q5: 92장
# Byeongeojjim:
#   Q1: 88장
#   Q2: 86장
#   Q3: 86장
#   Q4: 79장
#   Q5: 85장
# ChaesoTwigim:
#   Q1: 88장
#   Q2: 88장
#   Q3: 88장
#   Q4: 89장
#   Q5: 88장
# ChamchiMayoSamgakKimbap:
#   Q1: 86장
#   Q2: 87장
#   Q3: 88장
#   Q4: 88장
#   Q5: 89장
# ChickenWing:
#   Q1: 88장
#   Q2: 88장
#   Q3: 88장
#   Q4: 88장
#   Q5: 88장
# ChonggakKimchi:
#   Q1: 88장
#   Q2: 88장
#   Q3: 88장
#   Q4: 88장
#   Q5: 87장
# CornSoup:
#   Q1: 86장
#   Q2: 95장
#   Q3: 87장
#   Q4: 84장
#   Q5: 88장
# CreamSauceSpaghetti:
#   Q1: 88장
#   Q2: 91장
#   Q3: 88장
#   Q4: 89장
#   Q5: 92장
# CurryRice:
#   Q1: 88장
#   Q2: 87장
#   Q3: 87장
#   Q4: 87장
#   Q5: 85장
# Dakbokkeumtang:
#   Q1: 83장
#   Q2: 88장
#   Q3: 88장
#   Q4: 87장
#   Q5: 88장
# Dakgalbi:
#   Q1: 96장
#   Q2: 91장
#   Q3: 88장
#   Q4: 88장
#   Q5: 88장
# Dakjuk:
# ...

# %%
import os

# 최상위 디렉토리 경로
train_path = "D:/classification_data_resize/train/Quant_train_images"

# 클래스 폴더 목록 가져오기
class_list = os.listdir(train_path)

# 결과를 저장할 딕셔너리
result = {}
all_counts = []  # 모든 파일 개수를 저장할 리스트

# 각 클래스 폴더에 대해 Q1~Q5 폴더 순회
for class_name in class_list:
    class_path = os.path.join(train_path, class_name)
    q_count = {}
    
    # Q1 ~ Q5 폴더에 대해 파일 개수 세기
    for q in range(1, 6):
        q_folder_name = f"Q{q}"
        q_folder_path = os.path.join(class_path, q_folder_name)
        
        if os.path.isdir(q_folder_path):
            # Q 폴더에 있는 파일 개수 세기
            file_count = len([f for f in os.listdir(q_folder_path) if os.path.isfile(os.path.join(q_folder_path, f))])
            q_count[q_folder_name] = file_count
            all_counts.append(file_count)  # 파일 개수를 리스트에 추가
        else:
            # Q 폴더가 없는 경우 0으로 설정
            q_count[q_folder_name] = 0
            all_counts.append(0)  # 0을 리스트에 추가
    
    # 결과 저장
    result[class_name] = q_count

# 결과 출력
for class_name, counts in result.items():
    print(f"{class_name}:")
    for q_folder, count in counts.items():
        print(f"  {q_folder}: {count}장")

# 전체 파일 개수의 최소값과 최대값 계산
min_count = min(all_counts)
max_count = max(all_counts)

# 최소값과 최대값 출력
print("\n전체 Q 폴더의 파일 개수")
print(f"최소 파일 개수: {min_count}장")
print(f"최대 파일 개수: {max_count}장")

# 파일 개수가 가장 적은 클래스와 Q 폴더 찾기
min_index = all_counts.index(min_count)
min_class_index = min_index // 5  # 클래스 인덱스 계산 (5개의 Q 폴더가 있으므로)
min_q_index = min_index % 5  # Q 폴더 인덱스 계산

# 가장 적은 파일 개수를 가진 클래스와 Q 폴더 이름 출력
min_class_name = class_list[min_class_index]
min_q_folder = f"Q{min_q_index + 1}"
print(f"\n가장 적은 파일 개수를 가진 클래스: {min_class_name}")
print(f"가장 적은 파일 개수를 가진 Q 폴더: {min_q_folder}")
# Out:
# Albap:
#   Q1: 92장
#   Q2: 85장
#   Q3: 87장
#   Q4: 87장
#   Q5: 92장
# Altang:
#   Q1: 86장
#   Q2: 88장
#   Q3: 88장
#   Q4: 88장
#   Q5: 88장
# Budaejjigae:
#   Q1: 84장
#   Q2: 88장
#   Q3: 91장
#   Q4: 90장
#   Q5: 92장
# Byeongeojjim:
#   Q1: 88장
#   Q2: 86장
#   Q3: 86장
#   Q4: 79장
#   Q5: 85장
# ChaesoTwigim:
#   Q1: 88장
#   Q2: 88장
#   Q3: 88장
#   Q4: 89장
#   Q5: 88장
# ChamchiMayoSamgakKimbap:
#   Q1: 86장
#   Q2: 87장
#   Q3: 88장
#   Q4: 88장
#   Q5: 89장
# ChickenWing:
#   Q1: 88장
#   Q2: 88장
#   Q3: 88장
#   Q4: 88장
#   Q5: 88장
# ChonggakKimchi:
#   Q1: 88장
#   Q2: 88장
#   Q3: 88장
#   Q4: 88장
#   Q5: 87장
# CornSoup:
#   Q1: 86장
#   Q2: 95장
#   Q3: 87장
#   Q4: 84장
#   Q5: 88장
# CreamSauceSpaghetti:
#   Q1: 88장
#   Q2: 91장
#   Q3: 88장
#   Q4: 89장
#   Q5: 92장
# CurryRice:
#   Q1: 88장
#   Q2: 87장
#   Q3: 87장
#   Q4: 87장
#   Q5: 85장
# Dakbokkeumtang:
#   Q1: 83장
#   Q2: 88장
#   Q3: 88장
#   Q4: 87장
#   Q5: 88장
# Dakgalbi:
#   Q1: 96장
#   Q2: 91장
#   Q3: 88장
#   Q4: 88장
#   Q5: 88장
# Dakjuk:
# ...

# %%
import os

# 최상위 디렉토리 경로
train_path = "D:/classification_data_resize/valid/Quant_valid_images"

# 클래스 폴더 목록 가져오기
class_list = os.listdir(train_path)

# 결과를 저장할 딕셔너리
result = {}
all_counts = []  # 모든 파일 개수를 저장할 리스트

# 각 클래스 폴더에 대해 Q1~Q5 폴더 순회
for class_name in class_list:
    class_path = os.path.join(train_path, class_name)
    q_count = {}
    
    # Q1 ~ Q5 폴더에 대해 파일 개수 세기
    for q in range(1, 6):
        q_folder_name = f"Q{q}"
        q_folder_path = os.path.join(class_path, q_folder_name)
        
        if os.path.isdir(q_folder_path):
            # Q 폴더에 있는 파일 개수 세기
            file_count = len([f for f in os.listdir(q_folder_path) if os.path.isfile(os.path.join(q_folder_path, f))])
            q_count[q_folder_name] = file_count
            all_counts.append(file_count)  # 파일 개수를 리스트에 추가
        else:
            # Q 폴더가 없는 경우 0으로 설정
            q_count[q_folder_name] = 0
            all_counts.append(0)  # 0을 리스트에 추가
    
    # 결과 저장
    result[class_name] = q_count

# 결과 출력
for class_name, counts in result.items():
    print(f"{class_name}:")
    for q_folder, count in counts.items():
        print(f"  {q_folder}: {count}장")

# 전체 파일 개수의 최소값과 최대값 계산
min_count = min(all_counts)
max_count = max(all_counts)

# 최소값과 최대값 출력
print("\n전체 Q 폴더의 파일 개수")
print(f"최소 파일 개수: {min_count}장")
print(f"최대 파일 개수: {max_count}장")

# 파일 개수가 가장 적은 클래스와 Q 폴더 찾기
min_index = all_counts.index(min_count)
min_class_index = min_index // 5  # 클래스 인덱스 계산 (5개의 Q 폴더가 있으므로)
min_q_index = min_index % 5  # Q 폴더 인덱스 계산

# 가장 적은 파일 개수를 가진 클래스와 Q 폴더 이름 출력
min_class_name = class_list[min_class_index]
min_q_folder = f"Q{min_q_index + 1}"
print(f"\n가장 적은 파일 개수를 가진 클래스: {min_class_name}")
print(f"가장 적은 파일 개수를 가진 Q 폴더: {min_q_folder}")
# Out:
# Albap:
#   Q1: 11장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# Altang:
#   Q1: 11장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# Budaejjigae:
#   Q1: 10장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# Byeongeojjim:
#   Q1: 11장
#   Q2: 11장
#   Q3: 11장
#   Q4: 10장
#   Q5: 11장
# ChaesoTwigim:
#   Q1: 11장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# ChamchiMayoSamgakKimbap:
#   Q1: 11장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# ChickenWing:
#   Q1: 11장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# ChonggakKimchi:
#   Q1: 11장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# CornSoup:
#   Q1: 11장
#   Q2: 12장
#   Q3: 11장
#   Q4: 10장
#   Q5: 11장
# CreamSauceSpaghetti:
#   Q1: 11장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# CurryRice:
#   Q1: 11장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# Dakbokkeumtang:
#   Q1: 10장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# Dakgalbi:
#   Q1: 12장
#   Q2: 11장
#   Q3: 11장
#   Q4: 11장
#   Q5: 11장
# Dakjuk:
# ...
